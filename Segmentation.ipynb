# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.5/644.5 kB 6.7 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import roboflow
from roboflow import Roboflow

roboflow.login()

rf = Roboflow()

rf = Roboflow(api_key="VLtggLMmyWXrFmtyeplY")
project = rf.workspace("ken-huele").project("multiple-waste-ygguy")
dataset = project.version(1).download("yolov8")
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.200, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to Multiple-Waste-1 in yolov8:: 100%|██████████| 6590/6590 [00:01<00:00, 4732.80it/s]

# %%
# !yolo task=segment \
mode=train \
model=yolov8l-seg.pt \
data=/content/Multiple-Waste-1/data.yaml \
epochs=35
imgsz=640
# Out:
# ...
# 100% 88.1M/88.1M [00:01<00:00, 73.5MB/s]
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=segment \
mode=val \
model=/content/drive/MyDrive/Valo Shits/best.pt\
conf=0.25 \
source=/content/522317_gettyimages1325351577_726342.jpg
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 381, in entrypoint
#     check_dict_alignment(full_args_dict, {a: ''})
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 202, in check_dict_alignment
#     raise SyntaxError(string + CLI_HELP_MSG) from e
# SyntaxError: 'Shits/best.pt' is not a valid YOLO argument.
#
#     Arguments received: ['yolo', 'task=detect', 'mode=predict', 'model=/content/drive/MyDrive/Valo', 'Shits/best.pt', 'conf=0.25', 'source=/content/522317_gettyimages1325351577_726342.jpg']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
# ...

# %%
# !yolo task=segment \
mode=predict \
model=/content/runs/segment/train/weights/best.pt\
conf=0.25 \
source=/content/Multiple-Waste-1/test/images
# Out:
# Ultralytics YOLOv8.0.200 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l-seg summary (fused): 295 layers, 45914972 parameters, 0 gradients, 220.1 GFLOPs
#
# image 1/138 /content/Multiple-Waste-1/test/images/1574221890273-Copy-2-_jpg.rf.94b39634198b83f5009636c6bb7236c3.jpg: 640x640 2 Papers, 6 Plastics, 62.0ms
# image 2/138 /content/Multiple-Waste-1/test/images/18283512-recycling-garbage-and-reusable-waste-management-as-old-paper-glass-metal-and-plastic-household-1-Copy_jpg.rf.0528e902ff0fc87dbd68e8645f88f866.jpg: 640x640 7 Metals, 10 Papers, 8 Plastics, 54.0ms
# image 3/138 /content/Multiple-Waste-1/test/images/49147357-collage-of-plastic-waste-isolated-on-white-background-Copy-2-_jpg.rf.408d6dea999f79bdedcf51a3cf5dcf6c.jpg: 640x640 1 Metal, 3 Papers, 16 Plastics, 46.3ms
# image 4/138 /content/Multiple-Waste-1/test/images/7de63c6d-b802-4adf-99c2-d7d6d9dd7c3d-Copy-2-_jpg.rf.4649bc1cb60122f6662a7f3baaca7e16.jpg: 640x640 2 Metals, 8 Papers, 12 Plastics, 44.7ms
# ...
